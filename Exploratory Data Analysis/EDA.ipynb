# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
unemployment = pd.read_csv('Datasets/clean_unemployment.csv')
unemployment.head()
# Out:
#   country_code          country_name      continent   2010   2011   2012  \
# 0          AFG           Afghanistan           Asia  11.35  11.05  11.34
# 1          AGO                Angola         Africa   9.43   7.36   7.35
# 2          ALB               Albania         Europe  14.09  13.48  13.38
# 3          ARE  United Arab Emirates           Asia   2.48   2.30   2.18
# 4          ARG             Argentina  South America   7.71   7.18   7.22
#
#     2013   2014   2015   2016   2017   2018   2019   2020   2021
# 0  11.19  11.14  11.13  11.16  11.18  11.15  11.22  11.71  13.28
# 1   7.37   7.37   7.39   7.41   7.41   7.42   7.42   8.33   8.53
# 2  15.87  18.05  17.19  15.42  13.62  12.30  11.47  13.33  11.82
# 3   2.04   1.91   1.77   1.64   2.46   2.35   2.23   3.19   3.36
# 4   7.10   7.27   7.52   8.11   8.35   9.22   9.84  11.46  10.90

# %%
unemployment.dtypes
# Out:
# country_code     object
# country_name     object
# continent        object
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019            float64
# 2020            float64
# 2021            float64
# dtype: object

# %%
# for changing datatype of any column
unemployment["2010"]=unemployment["2010"].astype(int)
unemployment.dtypes
# Out:
# country_code     object
# country_name     object
# continent        object
# 2010              int32
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019            float64
# 2020            float64
# 2021            float64
# dtype: object

# %%
# changing it back to float because data is stored correctly here
unemployment["2010"]=unemployment["2010"].astype(float)
unemployment.dtypes
# Out:
# country_code     object
# country_name     object
# continent        object
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019            float64
# 2020            float64
# 2021            float64
# dtype: object

# %%
unemployment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_code  182 non-null    object
#  1   country_name  182 non-null    object
#  2   continent     177 non-null    object
#  3   2010          182 non-null    float64
#  4   2011          182 non-null    float64
#  5   2012          182 non-null    float64
#  6   2013          182 non-null    float64
#  7   2014          182 non-null    float64
#  8   2015          182 non-null    float64
#  9   2016          182 non-null    float64
#  10  2017          182 non-null    float64
#  11  2018          182 non-null    float64
#  12  2019          182 non-null    float64
#  13  2020          182 non-null    float64
#  14  2021          182 non-null    float64
# dtypes: float64(12), object(3)
# memory usage: 21.5+ KB

# %%
unemployment.describe()
# Out:
#              2010        2011        2012        2013        2014        2015  \
# count  182.000000  182.000000  182.000000  182.000000  182.000000  182.000000
# mean     7.928571    8.315440    8.317967    8.344780    8.179670    8.058901
# std      6.302710    6.266795    6.367270    6.416041    6.284241    6.161170
# min      0.000000    0.320000    0.480000    0.250000    0.200000    0.170000
# 25%      4.000000    3.775000    3.742500    3.692500    3.625000    3.662500
# 50%      6.000000    6.805000    6.690000    6.395000    6.450000    6.170000
# 75%     10.000000   11.045000   11.285000   11.310000   10.695000   10.215000
# max     32.000000   31.380000   31.020000   29.000000   28.030000   27.690000
#
#              2016        2017        2018        2019        2020        2021
# count  182.000000  182.000000  182.000000  182.000000  182.000000  182.000000
# mean     7.925879    7.668626    7.426429    7.243736    8.420934    8.390879
# ...

# %%
# show a full percent in each bin
sns.histplot(x="2021",data=unemployment, binwidth=1)
plt.show()

# %%
unemployment["continent"].isin(["Oceania"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 177     True
# 178    False
# 179    False
# 180    False
# 181    False
# Name: continent, Length: 182, dtype: bool

# %%
# Not Oceania (~)
~unemployment["continent"].isin(["Oceania"])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 177    False
# 178     True
# 179     True
# 180     True
# 181     True
# Name: continent, Length: 182, dtype: bool

# %%
unemployment[~unemployment["continent"].isin(["Oceania"])].head()
# Out:
#   country_code          country_name      continent  2010   2011   2012  \
# 0          AFG           Afghanistan           Asia  11.0  11.05  11.34
# 1          AGO                Angola         Africa   9.0   7.36   7.35
# 2          ALB               Albania         Europe  14.0  13.48  13.38
# 3          ARE  United Arab Emirates           Asia   2.0   2.30   2.18
# 4          ARG             Argentina  South America   7.0   7.18   7.22
#
#     2013   2014   2015   2016   2017   2018   2019   2020   2021
# 0  11.19  11.14  11.13  11.16  11.18  11.15  11.22  11.71  13.28
# 1   7.37   7.37   7.39   7.41   7.41   7.42   7.42   8.33   8.53
# 2  15.87  18.05  17.19  15.42  13.62  12.30  11.47  13.33  11.82
# 3   2.04   1.91   1.77   1.64   2.46   2.35   2.23   3.19   3.36
# 4   7.10   7.27   7.52   8.11   8.35   9.22   9.84  11.46  10.90

# %%
continent_summary = unemployment.groupby("continent").agg(
    mean_rate_2021 = ("2021","mean"), # mean_rate_2021 column is created 
    std_rate_2021 = ("2021","std"), # std_rate_2021 column is created 
)
continent_summary
# Out:
#                mean_rate_2021  std_rate_2021
# continent
# Africa              10.473585       8.131636
# Asia                 6.906170       5.414745
# Europe               7.414872       3.947825
# North America        9.155000       5.076482
# Oceania              4.280000       2.671522
# South America        9.924167       3.611624

# %%
sns.barplot(x="continent", y="2021", data=unemployment)
plt.show()

# %% [markdown]
# ## Missing Values
#
# - Drop missing values if they are 5% or less than of total values
# - If not then impute mean, median or mode

# %%
unemployment.isna().sum()
# Out:
# country_code    0
# country_name    0
# continent       5
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64

# %%
# Printing only those rows where data is missing
unemployment.loc[unemployment['continent'].isna(),:]
# Out:
#     country_code          country_name continent  2010   2011   2012   2013  \
# 65           GUM                  Guam       NaN   8.0  13.30  12.20  11.50
# 67           HKG  Hong Kong SAR, China       NaN   4.0   3.42   3.29   3.40
# 99           MAC      Macao SAR, China       NaN   2.0   2.56   1.97   1.82
# 117          NCL         New Caledonia       NaN  13.0  14.07  14.35  14.47
# 132          PRI           Puerto Rico       NaN  16.0  15.70  14.50  14.30
#
#       2014   2015   2016   2017   2018   2019   2020   2021
# 65    7.60   6.90   5.40   5.43   5.56   5.51   6.80   6.98
# 67    3.30   3.31   3.39   3.13   2.82   2.93   5.83   5.32
# 99    1.70   1.81   1.94   1.99   1.83   1.75   2.57   3.01
# 117  14.59  14.73  14.69  14.78  14.85  14.91  16.43  16.57
# 132  13.90  12.00  11.80  10.80   9.20   8.30   8.89   8.27

# %%
limit = len(unemployment) * 0.05 # 5% check
limit
# Out:
# 9.1

# %%
cols_to_drop = unemployment.columns[unemployment.isna().sum() <= limit]
cols_to_drop
# Out:
# Index(['country_code', 'country_name', 'continent', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
unemployment.dropna(subset = cols_to_drop, inplace = True)

# %%
unemployment.isna().sum()
# Out:
# country_code    0
# country_name    0
# continent       0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64

# %%
unemployment.head()
# Out:
#   country_code          country_name      continent  2010   2011   2012  \
# 0          AFG           Afghanistan           Asia  11.0  11.05  11.34
# 1          AGO                Angola         Africa   9.0   7.36   7.35
# 2          ALB               Albania         Europe  14.0  13.48  13.38
# 3          ARE  United Arab Emirates           Asia   2.0   2.30   2.18
# 4          ARG             Argentina  South America   7.0   7.18   7.22
#
#     2013   2014   2015   2016   2017   2018   2019   2020   2021
# 0  11.19  11.14  11.13  11.16  11.18  11.15  11.22  11.71  13.28
# 1   7.37   7.37   7.39   7.41   7.41   7.42   7.42   8.33   8.53
# 2  15.87  18.05  17.19  15.42  13.62  12.30  11.47  13.33  11.82
# 3   2.04   1.91   1.77   1.64   2.46   2.35   2.23   3.19   3.36
# 4   7.10   7.27   7.52   8.11   8.35   9.22   9.84  11.46  10.90

# %%
cols_with_missing_values = unemployment.columns[unemployment.isna().sum() > 0]
