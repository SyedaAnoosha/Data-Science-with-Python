# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gender=['Male','Female','Male','Male','Female','Male','Female','Female','Female','Female']
height=[65,67,68,61,60,71,77,78,75,78]
weight=[123,189,200,179,131,134,184,191,187,186]

# %%
sns.countplot(x=gender)
plt.show()

# %%
sns.scatterplot(x=height, y=weight)
plt.show()
